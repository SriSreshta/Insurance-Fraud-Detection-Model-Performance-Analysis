# %%
pip install pandas numpy scikit-learn xgboost matplotlib seaborn shap prophet pmdarima folium geopandas
# Out:
# ...
#   Using cached xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached shap-0.48.0-cp312-cp312-win_amd64.whl.metadata (25 kB)
# ...
#   Using cached prophet-1.1.7-py3-none-win_amd64.whl.metadata (3.6 kB)
# ...
#   Using cached pmdarima-2.0.4-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# ...
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached numba-0.61.2-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# ...
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached cmdstanpy-1.2.5-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached holidays-0.80-py3-none-any.whl.metadata (48 kB)
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached cython-3.1.3-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# ...

# %%
# !{sys.executable} -m pip install seaborn plotly
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
# Using cached xgboost-3.0.5-py3-none-win_amd64.whl (56.8 MB)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %%
df = pd.read_csv('data/insurance_claims.csv')

# %%
print(df.info())
print(df.head())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.replace('?', np.nan, inplace = True)
print(df.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
# to look for any missing values
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df['collision_type'] = df['collision_type'].fillna(df['collision_type'].mode()[0])
df['property_damage'] = df['property_damage'].fillna(df['property_damage'].mode()[0])
df['police_report_available'] = df['police_report_available'].fillna(df['police_report_available'].mode()[0])
df['authorities_contacted'] = df['police_report_available'].fillna(df['police_report_available'].mode()[0])
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
plt.figure(figsize = (18, 12))

corr = df.select_dtypes(include=['number']).corr()

sb.heatmap(data = corr, annot = True, fmt = '.2g', linewidth = 1)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['months_as_customer', 'age', 'policy_number', 'policy_bind_date', 'policy_state', 'policy_csl', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'capital-gains', 'capital-loss', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'property_damage', 'bodily_injuries', 'witnesses', 'police_report_available', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make', 'auto_model', 'auto_year', 'fraud_reported', '_c39']

# %%
df.drop(columns = ['age', 'total_claim_amount'], inplace = True, axis = 1)
df.head()
# Out:
#    months_as_customer  policy_number policy_bind_date policy_state policy_csl  \
# 0                 328         521585       17-10-2014           OH    250/500
# 1                 228         342868       27-06-2006           IN    250/500
# 2                 134         687698       06-09-2000           OH    100/300
# 3                 256         227811       25-05-1990           IL    250/500
# 4                 228         367455       06-06-2014           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0               1000                1406.91               0       466132
# 1               2000                1197.22         5000000       468176
# 2               2000                1413.14         5000000       430632
# 3               2000                1415.74         6000000       608117
# 4               1000                1583.91         6000000       610706
#
# ...

# %%
# X is the features and y is the target
X = df.drop(columns=['fraud_reported'])  
y = df['fraud_reported']

# %%
cat_df = X.select_dtypes(include = ['object'])
print(cat_df.head())
for col in cat_df.columns:
    print(f"{col}: \n{cat_df[col].unique()}\n")
# Out:
#   policy_bind_date policy_state policy_csl insured_sex  \
# 0       17-10-2014           OH    250/500        MALE
# 1       27-06-2006           IN    250/500        MALE
# 2       06-09-2000           OH    100/300      FEMALE
# 3       25-05-1990           IL    250/500      FEMALE
# 4       06-06-2014           IL   500/1000        MALE
#
#   insured_education_level insured_occupation insured_hobbies  \
# 0                      MD       craft-repair        sleeping
# 1                      MD  machine-op-inspct         reading
# 2                     PhD              sales     board-games
# 3                     PhD       armed-forces     board-games
# 4               Associate              sales     board-games
#
#   insured_relationship incident_date             incident_type  \
# 0              husband    25-01-2015  Single Vehicle Collision
# 1       other-relative    21-01-2015             Vehicle Theft
# 2            own-child    22-02-2015   Multi-vehicle Collision
# ...

# %%
cat_df = pd.get_dummies(cat_df, drop_first = True)
cat_df.head()
# Out:
#    policy_bind_date_01-01-2008  policy_bind_date_01-02-1990  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    policy_bind_date_01-02-1998  policy_bind_date_01-02-2011  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    policy_bind_date_01-03-1991  policy_bind_date_01-03-1997  \
# 0                        False                        False
# 1                        False                        False
# ...

# %%
num_df = X.select_dtypes(include = ['int64'])
num_df.head()
# Out:
#    months_as_customer  policy_number  policy_deductable  umbrella_limit  \
# 0                 328         521585               1000               0
# 1                 228         342868               2000         5000000
# 2                 134         687698               2000         5000000
# 3                 256         227811               2000         6000000
# 4                 228         367455               1000         6000000
#
#    insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 0       466132          53300             0                         5
# 1       468176              0             0                         8
# 2       430632          35100             0                         7
# 3       608117          48900        -62400                         5
# 4       610706          66000        -46000                        20
#
#    number_of_vehicles_involved  bodily_injuries  witnesses  injury_claim  \
# ...

# %%
X = pd.concat([num_df, cat_df], axis = 1)
X.head()
# Out:
#    months_as_customer  policy_number  policy_deductable  umbrella_limit  \
# 0                 328         521585               1000               0
# 1                 228         342868               2000         5000000
# 2                 134         687698               2000         5000000
# 3                 256         227811               2000         6000000
# 4                 228         367455               1000         6000000
#
#    insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 0       466132          53300             0                         5
# 1       468176              0             0                         8
# 2       430632          35100             0                         7
# 3       608117          48900        -62400                         5
# 4       610706          66000        -46000                        20
#
#    number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# ...

# %%
#outliers 
plt.figure(figsize = (20, 15))
plotnumber = 1

for col in X.columns:
    if plotnumber <= 24:
        ax = plt.subplot(5, 5, plotnumber)
        sb.boxplot(X[col])
        plt.xlabel(col, fontsize = 15)
    
    plotnumber += 1
plt.tight_layout()
plt.show()

# %%
#train test split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
X_train.head()
# Out:
#      months_as_customer  policy_number  policy_deductable  umbrella_limit  \
# 264                  84         942504               2000               0
# 298                 194         275092                500               0
# 753                 435         786432               2000               0
# 835                 370         528259               2000         7000000
# 230                 166         405533               1000               0
#
#      insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 264       457551          44400        -51500                         9
# 298       441659              0             0                         7
# 753       471784              0        -40000                        19
# 835       456203              0        -53200                         6
# 230       617774          65600        -68200                        18
#
#      number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# ...

# %%
num_df = X_train[['months_as_customer', 'policy_deductable', 'umbrella_limit',
       'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
       'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'injury_claim', 'property_claim',
       'vehicle_claim']]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(num_df)

scaled_num_df = pd.DataFrame(data = scaled_data, columns = num_df.columns, index = X_train.index)
scaled_num_df.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 264           -1.037261           1.382070       -0.484923       0.727559
# 298           -0.083822          -1.049249       -0.484923      -0.874984
# 753            2.005077           1.382070       -0.484923      -0.874984
# 835            1.441681           1.382070        2.535062      -0.874984
# 230           -0.326515          -0.238810       -0.484923       1.492738
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 264     -0.888333                 -0.396675                    -0.853039
# 298      0.945575                 -0.686219                    -0.853039
# 753     -0.478820                  1.051044                     1.103472
# 835     -0.948870                 -0.830991                    -0.853039
# 230     -1.483018                  0.906272                    -0.853039
#
#      bodily_injuries  witnesses  injury_claim  property_claim  vehicle_claim
# ...

# %%
X_train.drop(columns = scaled_num_df.columns, inplace = True)

# %%
X_train = pd.concat([scaled_num_df, X_train], axis = 1)
X_train.head()
X.dtypes
# Out:
# months_as_customer     int64
# policy_number          int64
# policy_deductable      int64
# umbrella_limit         int64
# insured_zip            int64
#                        ...
# auto_model_Tahoe        bool
# auto_model_Ultima       bool
# auto_model_Wrangler     bool
# auto_model_X5           bool
# auto_model_X6           bool
# Length: 2145, dtype: object

# %%
ids = X[['policy_number', 'insured_zip']]  # keep for later reference

# %%
X_model = X.drop(columns=['policy_number', 'insured_zip'], errors='ignore')
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, ids_train, ids_test = train_test_split(X_model, y, ids, test_size=0.2, random_state=42)

# %%
#1st model: random forest classifier
from sklearn.ensemble import RandomForestClassifier
rand_clf = RandomForestClassifier(criterion= 'entropy', max_depth= 10, max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 3, n_estimators= 140)
rand_clf.fit(X_train, y_train)
y_pred = rand_clf.predict(X_test)
results = ids_test.copy()
results['actual'] = y_test.values
results['predicted'] = y_pred
print(results.head())

# accuracy_score, confusion_matrix and classification_report
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
rand_clf_train_acc = accuracy_score(y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(y_test, y_pred)
print(f"Training accuracy of Random Forest is : {rand_clf_train_acc}")
print(f"Test accuracy of Random Forest is : {rand_clf_test_acc}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
#      policy_number  insured_zip actual predicted
# 521         924318       468872      N         N
# 737         180286       616583      N         N
# 740         178081       602842      N         N
# 660         991480       478486      N         N
# 411         630998       473645      N         N
# Training accuracy of Random Forest is : 0.76125
# Test accuracy of Random Forest is : 0.725
# [[145   0]
#  [ 55   0]]
#               precision    recall  f1-score   support
#
#            N       0.72      1.00      0.84       145
#            Y       0.00      0.00      0.00        55
#
#     accuracy                           0.72       200
#    macro avg       0.36      0.50      0.42       200
# weighted avg       0.53      0.72      0.61       200

# %%
# 2nd model: adaboost
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

# define base estimator
dtc = DecisionTreeClassifier(max_depth=1, random_state=42)

ada = AdaBoostClassifier(estimator=dtc, random_state=42)
parameters = {
    'n_estimators' : [50, 70, 90, 120, 180, 200],
    'learning_rate' : [0.001, 0.01, 0.1, 1, 10],
    'algorithm' : ['SAMME', 'SAMME.R']
}
grid_search = GridSearchCV(ada, parameters, n_jobs = -1, cv = 5, verbose = 1)
grid_search.fit(X_train, y_train_enc)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1,
#                                                                            random_state=42),
#                                           random_state=42),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 70, 90, 120, 180, 200]},
#              verbose=1)

# %%
# best parameter and best score
print(grid_search.best_params_)
print(grid_search.best_score_)

# best estimator 
ada = grid_search.best_estimator_
y_pred = ada.predict(X_test)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 90}
# 0.81125

# %%
results = ids_test.copy()
results['actual'] = y_test.values
results['predicted'] = y_pred
print(results.head())

# Training & test accuracy
ada_train_acc = accuracy_score(y_train_enc, ada.predict(X_train))
ada_test_acc = accuracy_score(y_test_enc, y_pred)
print(f"Training accuracy of AdaBoost: {ada_train_acc:.4f}")
print(f"Test accuracy of AdaBoost: {ada_test_acc:.4f}")
# Confusion matrix & report (use encoded test labels)
print(confusion_matrix(y_test_enc, y_pred))
print(classification_report(y_test_enc, y_pred, target_names=['N', 'Y']))
# Out:
#      policy_number  insured_zip actual  predicted
# 521         924318       468872      N          0
# 737         180286       616583      N          0
# 740         178081       602842      N          0
# 660         991480       478486      N          0
# 411         630998       473645      N          0
# Training accuracy of AdaBoost: 0.8462
# Test accuracy of AdaBoost: 0.7650
# [[132  13]
#  [ 34  21]]
#               precision    recall  f1-score   support
#
#            N       0.80      0.91      0.85       145
#            Y       0.62      0.38      0.47        55
#
#     accuracy                           0.77       200
#    macro avg       0.71      0.65      0.66       200
# weighted avg       0.75      0.77      0.75       200

# %%
# xgboost
y_train_enc = y_train.map({'N': 0, 'Y': 1})
y_test_enc  = y_test.map({'N': 0, 'Y': 1})
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state=42)
xgb.fit(X_train, y_train_enc)
y_pred = xgb.predict(X_test)

# accuracy_score, confusion_matrix and classification_report
xgb_train_acc = accuracy_score(y_train_enc, xgb.predict(X_train))
xgb_test_acc = accuracy_score(y_test_enc, y_pred)
results = ids_test.copy()
results['actual'] = y_test_enc.values
results['predicted'] = y_pred
print(results.head())

print(f"Training accuracy of XgBoost is : {xgb_train_acc}")
print(f"Test accuracy of XgBoost is : {xgb_test_acc}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test_enc, y_pred))
print("\nClassification Repost:\n", classification_report(y_test_enc, y_pred))
# Out:
#      policy_number  insured_zip  actual  predicted
# 521         924318       468872       0          0
# 737         180286       616583       0          0
# 740         178081       602842       0          0
# 660         991480       478486       0          0
# 411         630998       473645       0          0
# Training accuracy of XgBoost is : 1.0
# Test accuracy of XgBoost is : 0.755
#
# Confusion Matrix:
#  [[130  15]
#  [ 34  21]]
#
# Classification Repost:
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       145
#            1       0.58      0.38      0.46        55
#
#     accuracy                           0.76       200
#    macro avg       0.69      0.64      0.65       200
# weighted avg       0.74      0.76      0.74       200

# %%
#4th model: catboost classifier
from catboost import CatBoostClassifier
cat = CatBoostClassifier(iterations=10)
cat.fit(X_train, y_train_enc)
y_pred = cat.predict(X_test)
results = ids_test.copy()
results['actual'] = y_test_enc.values
results['predicted'] = y_pred
print(results.head())

# accuracy score, confusion matrix and classification report of cat boost
cat_acc = accuracy_score(y_test_enc, y_pred)
print(f"Training Accuracy of Cat Boost Classifier is {accuracy_score(y_train_enc, cat.predict(X_train))}")
print(f"Test Accuracy of Cat Boost Classifier is {cat_acc} \n")
print(f"Confusion Matrix :- \n{confusion_matrix(y_test_enc, y_pred)}\n")
print(f"Classification Report :- \n {classification_report(y_test_enc, y_pred)}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.5623260	total: 6.32ms	remaining: 56.9ms
# 1:	learn: 0.4863786	total: 12ms	remaining: 47.8ms
# 2:	learn: 0.3711186	total: 17.7ms	remaining: 41.3ms
# 3:	learn: 0.3266684	total: 23.3ms	remaining: 35ms
# 4:	learn: 0.3228256	total: 28.8ms	remaining: 28.8ms
# 5:	learn: 0.3207935	total: 34.4ms	remaining: 22.9ms
# 6:	learn: 0.3143045	total: 39.8ms	remaining: 17.1ms
# 7:	learn: 0.2927998	total: 45.2ms	remaining: 11.3ms
# 8:	learn: 0.2901839	total: 50.8ms	remaining: 5.64ms
# 9:	learn: 0.2881506	total: 56.4ms	remaining: 0us
#      policy_number  insured_zip  actual  predicted
# 521         924318       468872       0          0
# 737         180286       616583       0          0
# 740         178081       602842       0          0
# 660         991480       478486       0          0
# 411         630998       473645       0          0
# Training Accuracy of Cat Boost Classifier is 0.885
# Test Accuracy of Cat Boost Classifier is 0.775
#
# ...

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state=42)
xgb.fit(X_train, y_train_enc)
models = {
    "RandomForest": rand_clf,
    "AdaBoost": ada,
    "XGBoost": xgb,
    "CatBoost": cat
}
predictions = {}

#  Loop over models to make predictions
for name, model in models.items():
    y_pred = model.predict(X_test)
    if y_pred.dtype == object or isinstance(y_pred[0], str):
        y_pred = pd.Series(y_pred).map({'N':0, 'Y':1}).values
    predictions[name] = y_pred  # Keep as 0/1 for metrics

#  Save confusion matrices
for name, y_pred in predictions.items():
    cm = confusion_matrix(y_test_enc, y_pred)
    cm_df = pd.DataFrame(cm, index=['Actual_N','Actual_Y'], columns=['Pred_N','Pred_Y'])
    cm_df.to_csv(f"{name}_confusion_matrix.csv", index=False)

#  Save combined predictions CSV for Tableau

tableau_df = pd.DataFrame({"Actual": y_test_enc})
for name, y_pred in predictions.items():
    tableau_df[name + "_Pred"] = y_pred

# Map 0/1 to N/Y for readability in Tableau
tableau_df.replace({0:'N', 1:'Y'}, inplace=True)
tableau_df.to_csv("model_predictions_tableau.csv", index=False)

#  Save feature importances 

for name, model in models.items():
    if hasattr(model, "feature_importances_"):
        fi = pd.DataFrame({
            'feature': X_model.columns,
            'importance': model.feature_importances_
        }).sort_values('importance', ascending=False)
        fi.to_csv(f"{name}_feature_importances.csv", index=False)

# %%
from IPython.display import IFrame

# %%
tableau_link = "https://public.tableau.com/views/Con_Matrix_four_models/Sheet1?:embed=y&:display_count=n&:showVizHome=no"
# Display the dashboard
IFrame(tableau_link, width=900, height=700)
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="https://public.tableau.com/views/Con_Matrix_four_models/Sheet1?:embed=y&:display_count=n&:showVizHome=no"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Metric (for Fraud Class 'Y'/'1')	CatBoost	AdaBoost	XGBoost
# Recall (Ability to catch fraud)	    0.40 (Best)	 0.38	   0.38
# Precision (Reliability of alerts)	0.65 (Best)	 0.62	   0.58
# Actual Frauds Caught (TP)	        22	          21	     21
# Actual Frauds Missed (FN)	        33	          34	     34
# False Alarms (FP)	                12	          13	     15

# %% [markdown]
# Finally, the best model from the four tested is: CatBoost
